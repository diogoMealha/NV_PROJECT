# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
without_mag = np.array(np.load('C:/Users/Lucas/Desktop/NV_CENTER_PROJ/NV_PROJECT/img_analysis/june23_Largemagnet_imaging_withoutmag.npz',allow_pickle=True)["arr_0"],dtype=np.int16)
with_mag = np.array(np.load('C:/Users/Lucas/Desktop/NV_CENTER_PROJ/NV_PROJECT/img_analysis/june23_Largemagnet_imaging_withmag.npz',allow_pickle=True)["arr_0"],dtype=np.int16)

# %%
left = np.array(np.load('C:/Users/Lucas/Desktop/NV_CENTER_PROJ/NV_PROJECT/img_analysis/june23_Largemagnet_imaging_withmag_left2.npz')["arr_0"],dtype=np.int16)
right = np.array(np.load('C:/Users/Lucas/Desktop/NV_CENTER_PROJ/NV_PROJECT/img_analysis/june23_Largemagnet_imaging_withmag_right2.npz')["arr_0"],dtype=np.int16)

# %%
without_mag = np.array(np.load('C:/Users/Lucas/Desktop/NV_CENTER_PROJ/NV_PROJECT/img_analysis/june23_without_polymermagnet.npz',allow_pickle=True)["arr_0"],dtype=np.int16)
with_mag = np.array(np.load('C:/Users/Lucas/Desktop/NV_CENTER_PROJ/NV_PROJECT/img_analysis/june23_with_polymermagnet.npz',allow_pickle=True)["arr_0"],dtype=np.int16)

# %%
without_mag = np.array(np.load('C:/Users/Lucas/Desktop/NV_CENTER_PROJ/NV_PROJECT/img_analysis/june23_withlargemag_left.npz',allow_pickle=True)["arr_0"],dtype=np.int16)
with_mag = np.array(np.load('C:/Users/Lucas/Desktop/NV_CENTER_PROJ/NV_PROJECT/img_analysis/june23_withlargemag_right.npz',allow_pickle=True)["arr_0"],dtype=np.int16)

# %%
diff =  (-with_mag + without_mag)
diff
# Out:
# array([[-10,  16,  -4, ...,   0,   0,   1],
#        [-17,  -5,  -3, ...,  -3, -12,   0],
#        [ -1,  13,  -1, ...,  -2,  -3,   4],
#        ...,
#        [ -3,  -6, -15, ...,   0,   2,  -5],
#        [-13, -12,   0, ...,   5,   7,  -1],
#        [  2,  -5,  -8, ...,   4,  -7,  -3]], dtype=int16)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(with_mag, cmap='gray')
plt.colorbar()
plt.title('With Magnet')
# Out:
# Text(0.5, 1.0, 'With Magnet')

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(without_mag, cmap='gray')
plt.colorbar()
plt.title('Without Magnet')
# Out:
# Text(0.5, 1.0, 'Without Magnet')

# %%
plt.plot(without_mag[700,0:2000])
plt.plot(with_mag[700,0:2000])
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(diff, cmap='gray')
plt.colorbar()
plt.title('Difference (Without - With)')
# Out:
# Text(0.5, 1.0, 'Difference (Without - With)')

# %%
diff
# Out:
# array([[-10,  16,  -4, ...,   0,   0,   1],
#        [-17,  -5,  -3, ...,  -3, -12,   0],
#        [ -1,  13,  -1, ...,  -2,  -3,   4],
#        ...,
#        [ -3,  -6, -15, ...,   0,   2,  -5],
#        [-13, -12,   0, ...,   5,   7,  -1],
#        [  2,  -5,  -8, ...,   4,  -7,  -3]], dtype=int16)

# %%
plt.plot(np.divide(diff,without_mag)[700])

# %%
plt.plot(diff[700])

# %%
plt.plot(without_mag[700])

# %%
diffleftright=-left+right
diffleftright[500,400,]
# Out:
# 12

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(diffleftright, cmap='gray')
plt.colorbar()
plt.title('Difference (Without - With)')
# Out:
# Text(0.5, 1.0, 'Difference (Without - With)')

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(np.divide(diffleftright[400:1000,500:1350],1/2*left[400:1000,500:1350]+1/2*right[400:1000,500:1350]), cmap='gray')
plt.colorbar()
plt.title('Difference left right')
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(diff[400:1000,500:1350], cmap='gray')
plt.colorbar()
plt.title('Difference (Without - With)') 
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(without_mag[400:1000,500:1350]-right[400:1000,500:1350], cmap='gray')
plt.colorbar()
plt.title('Difference (Without - right)')
# Out:
# Text(0.5, 1.0, 'Difference (Without - right)')

# %%
np.divide(diffleftright,1/2*left+1/2*right)[700]
# Out:
# array([ 0.07162534, -0.03428571,  0.00550964, ..., -0.19607843,
#        -0.14285714,  0.        ])

# %%
plt.plot(np.divide(diffleftright,1/2*left+1/2*right)[700])

# %%
plt.plot(right[700])
plt.plot(left[700])
plt.show()
